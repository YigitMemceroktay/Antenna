# %%
from pathlib import Path
import pandas as pd

# Folder that contains the 5 geometry input files
base_dir = Path("../data/LHS")
print(base_dir)
# Explicitly target the 5 files (seed000 ... seed004)
files = [
    base_dir / f"input_trials_done_LHS_n20_rounded_seed{seed:03d}.csv"
    for seed in range(5)
]

all_ranges = []

for file_path in files:
    df = pd.read_csv(file_path)

    # Geometry parameter columns are all columns in these files
    parameter_ranges = pd.DataFrame({
        "parameter": df.columns,
        "min": df.min(numeric_only=True).values,
        "max": df.max(numeric_only=True).values,
    })
    parameter_ranges["span"] = parameter_ranges["max"] - parameter_ranges["min"]
    parameter_ranges["seed_file"] = file_path.name

    all_ranges.append(parameter_ranges)

# Long-format result: one row per (seed_file, parameter)
ranges_long = pd.concat(all_ranges, ignore_index=True)

# Reorder columns for readability
ranges_long = ranges_long[["seed_file", "parameter", "min", "max", "span"]]

# Print all results
print(ranges_long.to_string(index=False))

# Optional: save to CSV
out_file = base_dir / "geometry_parameter_ranges_by_seed.csv"
ranges_long.to_csv(out_file, index=False)
print(f"\nSaved: {out_file}")

# Optional: pivot view (easy comparison across seeds)
ranges_pivot = ranges_long.pivot_table(
    index="parameter",
    columns="seed_file",
    values=["min", "max", "span"]
)
print("\nPivot view:")
print(ranges_pivot)
# Out:
# ..\data\LHS
#                                     seed_file                                  parameter   min   max  span
# input_trials_done_LHS_n20_rounded_seed000.csv                            length of patch 1.917 5.031 3.114
# input_trials_done_LHS_n20_rounded_seed000.csv                             width of patch 1.924 5.076 3.152
# input_trials_done_LHS_n20_rounded_seed000.csv                            height of patch 0.010 0.039 0.029
# input_trials_done_LHS_n20_rounded_seed000.csv                        height of substrate 0.133 0.783 0.650
# input_trials_done_LHS_n20_rounded_seed000.csv              height of solder resist layer 0.021 0.096 0.075
# input_trials_done_LHS_n20_rounded_seed000.csv                        radius of the probe 0.015 0.049 0.034
# input_trials_done_LHS_n20_rounded_seed000.csv                                      c_pad 0.001 0.024 0.023
# input_trials_done_LHS_n20_rounded_seed000.csv                                  c_antipad 0.025 0.098 0.073
# input_trials_done_LHS_n20_rounded_seed000.csv                                    c_probe 0.060 0.440 0.380
# input_trials_done_LHS_n20_rounded_seed000.csv           dielectric constant of substrate 2.140 4.850 2.710
# input_trials_done_LHS_n20_rounded_seed000.csv dielectric constant of solder resist layer 2.040 4.980 2.940
# input_trials_done_LHS_n20_rounded_seed001.csv                            length of patch 1.814 5.197 3.383
# input_trials_done_LHS_n20_rounded_seed001.csv                             width of patch 1.846 5.146 3.300
# input_trials_done_LHS_n20_rounded_seed001.csv                            height of patch 0.010 0.040 0.030
# input_trials_done_LHS_n20_rounded_seed001.csv                        height of substrate 0.102 0.777 0.675
# input_trials_done_LHS_n20_rounded_seed001.csv              height of solder resist layer 0.023 0.098 0.075
# input_trials_done_LHS_n20_rounded_seed001.csv                        radius of the probe 0.017 0.049 0.032
# input_trials_done_LHS_n20_rounded_seed001.csv                                      c_pad 0.001 0.024 0.023
# input_trials_done_LHS_n20_rounded_seed001.csv                                  c_antipad 0.026 0.100 0.074
# input_trials_done_LHS_n20_rounded_seed001.csv                                    c_probe 0.050 0.440 0.390
# input_trials_done_LHS_n20_rounded_seed001.csv           dielectric constant of substrate 2.100 4.940 2.840
# input_trials_done_LHS_n20_rounded_seed001.csv dielectric constant of solder resist layer 2.110 4.970 2.860
# input_trials_done_LHS_n20_rounded_seed002.csv                            length of patch 1.922 5.164 3.242
# input_trials_done_LHS_n20_rounded_seed002.csv                             width of patch 1.805 5.068 3.263
# input_trials_done_LHS_n20_rounded_seed002.csv                            height of patch 0.010 0.040 0.030
# input_trials_done_LHS_n20_rounded_seed002.csv                        height of substrate 0.119 0.797 0.678
# input_trials_done_LHS_n20_rounded_seed002.csv              height of solder resist layer 0.022 0.098 0.076
# input_trials_done_LHS_n20_rounded_seed002.csv                        radius of the probe 0.016 0.048 0.032
# input_trials_done_LHS_n20_rounded_seed002.csv                                      c_pad 0.001 0.024 0.023
# input_trials_done_LHS_n20_rounded_seed002.csv                                  c_antipad 0.025 0.096 0.071
# input_trials_done_LHS_n20_rounded_seed002.csv                                    c_probe 0.060 0.440 0.380
# input_trials_done_LHS_n20_rounded_seed002.csv           dielectric constant of substrate 2.150 4.910 2.760
# input_trials_done_LHS_n20_rounded_seed002.csv dielectric constant of solder resist layer 2.020 4.920 2.900
# input_trials_done_LHS_n20_rounded_seed003.csv                            length of patch 1.827 5.167 3.340
# input_trials_done_LHS_n20_rounded_seed003.csv                             width of patch 1.841 5.187 3.346
# input_trials_done_LHS_n20_rounded_seed003.csv                            height of patch 0.010 0.039 0.029
# input_trials_done_LHS_n20_rounded_seed003.csv                        height of substrate 0.122 0.795 0.673
# input_trials_done_LHS_n20_rounded_seed003.csv              height of solder resist layer 0.021 0.097 0.076
# input_trials_done_LHS_n20_rounded_seed003.csv                        radius of the probe 0.016 0.050 0.034
# input_trials_done_LHS_n20_rounded_seed003.csv                                      c_pad 0.000 0.025 0.025
# input_trials_done_LHS_n20_rounded_seed003.csv                                  c_antipad 0.025 0.097 0.072
# input_trials_done_LHS_n20_rounded_seed003.csv                                    c_probe 0.060 0.440 0.380
# input_trials_done_LHS_n20_rounded_seed003.csv           dielectric constant of substrate 2.040 4.970 2.930
# input_trials_done_LHS_n20_rounded_seed003.csv dielectric constant of solder resist layer 2.150 4.850 2.700
# input_trials_done_LHS_n20_rounded_seed004.csv                            length of patch 1.870 5.081 3.211
# input_trials_done_LHS_n20_rounded_seed004.csv                             width of patch 1.880 5.154 3.274
# input_trials_done_LHS_n20_rounded_seed004.csv                            height of patch 0.011 0.040 0.029
# input_trials_done_LHS_n20_rounded_seed004.csv                        height of substrate 0.108 0.775 0.667
# input_trials_done_LHS_n20_rounded_seed004.csv              height of solder resist layer 0.022 0.098 0.076
# input_trials_done_LHS_n20_rounded_seed004.csv                        radius of the probe 0.016 0.049 0.033
# input_trials_done_LHS_n20_rounded_seed004.csv                                      c_pad 0.000 0.024 0.024
# input_trials_done_LHS_n20_rounded_seed004.csv                                  c_antipad 0.027 0.097 0.070
# input_trials_done_LHS_n20_rounded_seed004.csv                                    c_probe 0.050 0.440 0.390
# input_trials_done_LHS_n20_rounded_seed004.csv           dielectric constant of substrate 2.090 4.890 2.800
# input_trials_done_LHS_n20_rounded_seed004.csv dielectric constant of solder resist layer 2.030 4.890 2.860
#
# Saved: ..\data\LHS\geometry_parameter_ranges_by_seed.csv
#
# Pivot view:
#                                                                                      max  \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed000.csv
# parameter
# c_antipad                                                                          0.098
# c_pad                                                                              0.024
# c_probe                                                                            0.440
# dielectric constant of solder resist layer                                         4.980
# dielectric constant of substrate                                                   4.850
# height of patch                                                                    0.039
# height of solder resist layer                                                      0.096
# height of substrate                                                                0.783
# length of patch                                                                    5.031
# radius of the probe                                                                0.049
# width of patch                                                                     5.076
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed001.csv
# parameter
# c_antipad                                                                          0.100
# c_pad                                                                              0.024
# c_probe                                                                            0.440
# dielectric constant of solder resist layer                                         4.970
# dielectric constant of substrate                                                   4.940
# height of patch                                                                    0.040
# height of solder resist layer                                                      0.098
# height of substrate                                                                0.777
# length of patch                                                                    5.197
# radius of the probe                                                                0.049
# width of patch                                                                     5.146
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed002.csv
# parameter
# c_antipad                                                                          0.096
# c_pad                                                                              0.024
# c_probe                                                                            0.440
# dielectric constant of solder resist layer                                         4.920
# dielectric constant of substrate                                                   4.910
# height of patch                                                                    0.040
# height of solder resist layer                                                      0.098
# height of substrate                                                                0.797
# length of patch                                                                    5.164
# radius of the probe                                                                0.048
# width of patch                                                                     5.068
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed003.csv
# parameter
# c_antipad                                                                          0.097
# c_pad                                                                              0.025
# c_probe                                                                            0.440
# dielectric constant of solder resist layer                                         4.850
# dielectric constant of substrate                                                   4.970
# height of patch                                                                    0.039
# height of solder resist layer                                                      0.097
# height of substrate                                                                0.795
# length of patch                                                                    5.167
# radius of the probe                                                                0.050
# width of patch                                                                     5.187
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed004.csv
# parameter
# c_antipad                                                                          0.097
# c_pad                                                                              0.024
# c_probe                                                                            0.440
# dielectric constant of solder resist layer                                         4.890
# dielectric constant of substrate                                                   4.890
# height of patch                                                                    0.040
# height of solder resist layer                                                      0.098
# height of substrate                                                                0.775
# length of patch                                                                    5.081
# radius of the probe                                                                0.049
# width of patch                                                                     5.154
#
#                                                                                      min  \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed000.csv
# parameter
# c_antipad                                                                          0.025
# c_pad                                                                              0.001
# c_probe                                                                            0.060
# dielectric constant of solder resist layer                                         2.040
# dielectric constant of substrate                                                   2.140
# height of patch                                                                    0.010
# height of solder resist layer                                                      0.021
# height of substrate                                                                0.133
# length of patch                                                                    1.917
# radius of the probe                                                                0.015
# width of patch                                                                     1.924
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed001.csv
# parameter
# c_antipad                                                                          0.026
# c_pad                                                                              0.001
# c_probe                                                                            0.050
# dielectric constant of solder resist layer                                         2.110
# dielectric constant of substrate                                                   2.100
# height of patch                                                                    0.010
# height of solder resist layer                                                      0.023
# height of substrate                                                                0.102
# length of patch                                                                    1.814
# radius of the probe                                                                0.017
# width of patch                                                                     1.846
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed002.csv
# parameter
# c_antipad                                                                          0.025
# c_pad                                                                              0.001
# c_probe                                                                            0.060
# dielectric constant of solder resist layer                                         2.020
# dielectric constant of substrate                                                   2.150
# height of patch                                                                    0.010
# height of solder resist layer                                                      0.022
# height of substrate                                                                0.119
# length of patch                                                                    1.922
# radius of the probe                                                                0.016
# width of patch                                                                     1.805
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed003.csv
# parameter
# c_antipad                                                                          0.025
# c_pad                                                                              0.000
# c_probe                                                                            0.060
# dielectric constant of solder resist layer                                         2.150
# dielectric constant of substrate                                                   2.040
# height of patch                                                                    0.010
# height of solder resist layer                                                      0.021
# height of substrate                                                                0.122
# length of patch                                                                    1.827
# radius of the probe                                                                0.016
# width of patch                                                                     1.841
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed004.csv
# parameter
# c_antipad                                                                          0.027
# c_pad                                                                              0.000
# c_probe                                                                            0.050
# dielectric constant of solder resist layer                                         2.030
# dielectric constant of substrate                                                   2.090
# height of patch                                                                    0.011
# height of solder resist layer                                                      0.022
# height of substrate                                                                0.108
# length of patch                                                                    1.870
# radius of the probe                                                                0.016
# width of patch                                                                     1.880
#
#                                                                                     span  \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed000.csv
# parameter
# c_antipad                                                                          0.073
# c_pad                                                                              0.023
# c_probe                                                                            0.380
# dielectric constant of solder resist layer                                         2.940
# dielectric constant of substrate                                                   2.710
# height of patch                                                                    0.029
# height of solder resist layer                                                      0.075
# height of substrate                                                                0.650
# length of patch                                                                    3.114
# radius of the probe                                                                0.034
# width of patch                                                                     3.152
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed001.csv
# parameter
# c_antipad                                                                          0.074
# c_pad                                                                              0.023
# c_probe                                                                            0.390
# dielectric constant of solder resist layer                                         2.860
# dielectric constant of substrate                                                   2.840
# height of patch                                                                    0.030
# height of solder resist layer                                                      0.075
# height of substrate                                                                0.675
# length of patch                                                                    3.383
# radius of the probe                                                                0.032
# width of patch                                                                     3.300
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed002.csv
# parameter
# c_antipad                                                                          0.071
# c_pad                                                                              0.023
# c_probe                                                                            0.380
# dielectric constant of solder resist layer                                         2.900
# dielectric constant of substrate                                                   2.760
# height of patch                                                                    0.030
# height of solder resist layer                                                      0.076
# height of substrate                                                                0.678
# length of patch                                                                    3.242
# radius of the probe                                                                0.032
# width of patch                                                                     3.263
#
#                                                                                           \
# seed_file                                  input_trials_done_LHS_n20_rounded_seed003.csv
# parameter
# c_antipad                                                                          0.072
# c_pad                                                                              0.025
# c_probe                                                                            0.380
# dielectric constant of solder resist layer                                         2.700
# dielectric constant of substrate                                                   2.930
# height of patch                                                                    0.029
# height of solder resist layer                                                      0.076
# height of substrate                                                                0.673
# length of patch                                                                    3.340
# radius of the probe                                                                0.034
# width of patch                                                                     3.346
#
#
# seed_file                                  input_trials_done_LHS_n20_rounded_seed004.csv
# parameter
# c_antipad                                                                          0.070
# c_pad                                                                              0.024
# c_probe                                                                            0.390
# dielectric constant of solder resist layer                                         2.860
# dielectric constant of substrate                                                   2.800
# height of patch                                                                    0.029
# height of solder resist layer                                                      0.076
# height of substrate                                                                0.667
# length of patch                                                                    3.211
# radius of the probe                                                                0.033
# width of patch                                                                     3.274
